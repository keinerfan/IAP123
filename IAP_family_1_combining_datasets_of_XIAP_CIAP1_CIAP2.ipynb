# %% [markdown]
# <a href="https://colab.research.google.com/github/keinerfan/IAP123/blob/main/IAP_family_1_combining_datasets_of_XIAP_CIAP1_CIAP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 822.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search  XIAP**

# %%
# Target search for coronavirus
target = new_client.target

target_query = target.search('IAP')
# Initialize the ChEMBL activity client to fetch bioassay data

# %%
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'Q9JKS8', 'xref_name': None, 'xre...  Rattus norvegicus
# 1                                                  []       Mus musculus
# 2   [{'xref_id': 'P98170', 'xref_name': None, 'xre...       Homo sapiens
# 3                                                  []       Homo sapiens
# 4                                                  []       Homo sapiens
# 5                                                  []       Homo sapiens
# 6   [{'xref_id': 'P09923', 'xref_name': None, 'xre...       Homo sapiens
# 7   [{'xref_id': 'P19111', 'xref_name': None, 'xre...         Bos taurus
# 8   [{'xref_id': 'Q96CA5', 'xref_name': None, 'xre...       Homo sapiens
# 9                                                  []       Homo sapiens
# 10                                                 []       Homo sapiens
# 11                                                 []       Homo sapiens
# ...

# %% [markdown]
# :### **Select and retrieve bioactivity data for *XIAP)**

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL4198'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df_xiap = pd.DataFrame.from_dict(res)

# %%
df_xiap
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2539  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2540  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2541  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2542  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2543  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# # **Target search for CIAP2**

# %% [markdown]
# :### **Select and retrieve bioactivity data for *XIAP)**

# %%
selected_target = targets.target_chembl_id[18]
selected_target
# Out:
# 'CHEMBL5335'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df_ciap2 = pd.DataFrame.from_dict(res)

# %%
df_ciap2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 199  {'action_type': 'ANTAGONIST', 'description': '...             None
# 200  {'action_type': 'ANTAGONIST', 'description': '...             None
# 201  {'action_type': 'ANTAGONIST', 'description': '...             None
# 202  {'action_type': 'ANTAGONIST', 'description': '...             None
# 203  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# # **Target search for CIAP-1**

# %%
selected_target = targets.target_chembl_id[19]
selected_target
# Out:
# 'CHEMBL5462'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df_ciap3 = pd.DataFrame.from_dict(res)

# %%
df_ciap3
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 725  {'action_type': 'ANTAGONIST', 'description': '...             None
# 726  {'action_type': 'ANTAGONIST', 'description': '...             None
# 727  {'action_type': 'ANTAGONIST', 'description': '...             None
# 728  {'action_type': 'ANTAGONIST', 'description': '...             None
# 729  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# # **combining 3 dataframes**

# %%
df = pd.concat([df_xiap, df_ciap2, df_ciap3] , axis=0 , ignore_index = True)
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3473  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3474  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3475  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3476  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3477  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('IAP123_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-37-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3473  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3474  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3475  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3476  {'action_type': 'ANTAGONIST', 'description': '...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1640

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None      1107573                  []
# 1           None             None      1111067                  []
# 2           None             None      1113344                  []
# 3           None             None      1116988                  []
# 7           None             None      1140305                  []
# ...          ...              ...          ...                 ...
# 3396        None             None     18084852                  []
# 3397        None             None     18084853                  []
# 3398        None             None     18084854                  []
# 3399        None             None     18084855                  []
# 3400        None             None     18084856                  []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL650031  Compound was tested for inhibitory activity to...
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL441156  C[C@H](N)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CCC[C@...
# 1          CHEMBL221137                  CCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O
# 2          CHEMBL414396  CC[C@H](C)[C@H](NC(=O)[C@H]1CCCN1C(=O)[C@@H](N...
# 3          CHEMBL404788  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
# 7          CHEMBL310987  C[C@H](N)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CCC[C@...
# ...                 ...                                                ...
# 3396      CHEMBL4084120  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 3397      CHEMBL4091245  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 3398      CHEMBL4070316  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 3399      CHEMBL4079500  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 3400      CHEMBL4097534  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
#
#      standard_value
# 0             570.0
# 1            4100.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('IAP123_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('IAP123_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL441156  C[C@H](N)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CCC[C@...
# 1          CHEMBL221137                  CCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O
# 2          CHEMBL414396  CC[C@H](C)[C@H](NC(=O)[C@H]1CCCN1C(=O)[C@@H](N...
# 3          CHEMBL404788  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
# 4          CHEMBL310987  C[C@H](N)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CCC[C@...
# ...                 ...                                                ...
# 1635      CHEMBL4084120  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 1636      CHEMBL4091245  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 1637      CHEMBL4070316  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 1638      CHEMBL4079500  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
# 1639      CHEMBL4097534  CC[C@H](NC)C(=O)N[C@@H]1C(=O)N2[C@@H](CC[C@@H]...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('IAP123_03_bioactivity_data_curated.csv', index=False)

# %%
! zip IAP123.zip *.csv
# Out:
#   adding: IAP123_01_bioactivity_data_raw.csv (deflated 95%)
#   adding: IAP123_02_bioactivity_data_preprocessed.csv (deflated 85%)
#   adding: IAP123_03_bioactivity_data_curated.csv (deflated 86%)

# %%
! ls -l
# Out:
# total 4040
# -rw-r--r-- 1 root root  229856 Jul 27 09:44 CIAP1.zip
# -rw-r--r-- 1 root root 3304832 Jul 27 09:40 IAP123_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  171571 Jul 27 09:41 IAP123_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  185495 Jul 27 09:44 IAP123_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  229856 Jul 27 09:44 IAP123.zip
# drwxr-xr-x 1 root root    4096 Jul 25 13:21 sample_data

# %% [markdown]
# ---
